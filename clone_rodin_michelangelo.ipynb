# %% [markdown]
# <a href="https://colab.research.google.com/github/sergey-frd/rodin_michelangelo_train/blob/master/clone_rodin_michelangelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/sergey-frd/rodin_michelangelo_train
# Out:
# Cloning into 'rodin_michelangelo_train'...
# remote: Enumerating objects: 311, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (311/311), done.
# remote: Total 311 (delta 0), reused 311 (delta 0), pack-reused 0
# Receiving objects: 100% (311/311), 37.75 MiB | 34.95 MiB/s, done.

# %%
! git clone https://github.com/sergey-frd/rodin_michelangelo_test
# Out:
# Cloning into 'rodin_michelangelo_test'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 117 (delta 0), reused 117 (delta 0), pack-reused 0
# Receiving objects: 100% (117/117), 15.31 MiB | 42.04 MiB/s, done.
